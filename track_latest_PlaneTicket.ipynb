# %% [markdown]
# # Best Ticket price program

# %% [markdown]
# ### Next Step
# -  Step1 : Get ticket website
# -  Step2 : Remember the last three start & end location
# -  Step3 : Frontend Design

# %%
# ! pip install BeautifulSoup4
# ! pip install selenium --upgrade
# ! pip install langchain --upgrade
# ! wget https://chromedriver.storage.googleapis.com/114.0.5735.90/chromedriver_win32.zip -- Linux

# %%
# A.Import neccessary package and OpenAI API Tool
import pandas 
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.chains import create_extraction_chain

OPENAI_API_KEY = "YOUROPENAIAPI" 
OPENAI_LLM = ChatOpenAI(temperature=0, model="gpt-3.5-turbo-0613", openai_api_key = OPENAI_API_KEY)
website_expedia_ticket = True

# %%
# B.crawler_flightdataby_LLM
def crawler_flightdataby_LLM(OPENAI_API_KEY,OPENAI_LLM, website_expedia_ticket):
    
    # 1.Craw data from website and using beautiful soup filter data
    s = Service('./chromedriver')
    driver = webdriver.Chrome(service = s)
    driver.get(Ticket_Website)

    
    #2.Design Agent(Langchain) mission(Dictionary) by setting the customize schema 
    if website_expedia_ticket : 
        soup = BeautifulSoup(driver.page_source, 'lxml')
        print(soup.text)
        schema = {
            "properties": {
                "flight": {"type": "string"},
                "departure_time": {"type": "string"},
                "departure_terminal": {"type": "string"},
                "flight_hour": {"type": "string"},
                "flight_type": {"type": "string"},
                "arrival_time": {"type": "string"},
                "arrival_terminal": {"type": "string"},
                "price": {"type": "string"},
                "flight_type": {"type": "string"},
            }
        }
    else :
        print("skyscanner")
        soup = BeautifulSoup(driver.page_source)
        print(soup.text)
        schema = {
            "properties": {
                "flight": {"type": "string"},
                "departure_time": {"type": "string"},
                "departure_terminal": {"type": "string"},
                "flight_hour": {"type": "string"},
                "flight_type": {"type": "string"},
                "arrival_time": {"type": "string"},
                "arrival_terminal": {"type": "string"},
                "price": {"type": "string"},
                "flight_type": {"type": "string"},
            }
        }
#     else : 
#         print("Hotel")
#         schema = {
#             "properties": {
#                 "Hotel_Name": {"type": "string"},
#                 "price": {"type": "string"},
#                 "Reviews": {"type": "string"},                
#             }
#         }
    
    #3.Extract data using OPENAI API and show data by df 
    chain = create_extraction_chain(schema, OPENAI_LLM)
    flight_data = chain.run(soup.text)
    df = pandas.DataFrame(flight_data)
#     df.to_csv('ticket_out.csv', index=False)
    display(df)

# %%
if website_expedia_ticket : 
    Ticket_Website = "https://www.expedia.com.tw/Flights-Search?leg1=from%3A%E5%8F%B0%E5%8C%97%20%28TPE-%E6%A1%83%E5%9C%92%E5%9C%8B%E9%9A%9B%E6%A9%9F%E5%A0%B4%29%2Cto%3A%E6%9B%BC%E8%B0%B7%20%28BKK%20-%20%E7%B4%A0%E8%90%AC%E9%82%A3%E6%99%AE%E5%9C%8B%E9%9A%9B%E6%A9%9F%E5%A0%B4%29%2Cdeparture%3A2023%2F7%2F12TANYT&leg2=from%3A%E6%9B%BC%E8%B0%B7%20%28BKK%20-%20%E7%B4%A0%E8%90%AC%E9%82%A3%E6%99%AE%E5%9C%8B%E9%9A%9B%E6%A9%9F%E5%A0%B4%29%2Cto%3A%E5%8F%B0%E5%8C%97%20%28TPE-%E6%A1%83%E5%9C%92%E5%9C%8B%E9%9A%9B%E6%A9%9F%E5%A0%B4%29%2Cdeparture%3A2023%2F7%2F13TANYT&mode=search&options=carrier%3A%2A%2Ccabinclass%3A%2Cmaxhops%3A1%2Cnopenalty%3AN&pageId=0&passengers=adults%3A1%2Cchildren%3A0%2Cinfantinlap%3AN&trip=roundtrip"
    crawler_flightdataby_LLM(OPENAI_API_KEY,OPENAI_LLM, website_expedia_ticket)

else :
    print("skyscanner")
    Ticket_Website = "https://www.skyscanner.com.tw/transport/flights/tpet/nrt/230705/230712/?adults=1&adultsv2=1&cabinclass=economy&children=0&childrenv2=&destinationentityid=27542089&inboundaltsenabled=false&infants=0&outboundaltsenabled=false&preferdirects=false&ref=home&rtn=1"
    crawler_flightdataby_LLM(OPENAI_API_KEY,OPENAI_LLM, website_expedia_ticket)
# else :
#     print("Hotel")
#     Ticket_Website = "https://www.expedia.com.tw/Hotel-Search?adults=2&children=&destination=%E6%B0%B4%E6%98%8E%E6%BC%BE%2C%20%E5%B3%87%E9%87%8C%E5%B3%B6%2C%20%E5%8D%B0%E5%B0%BC&endDate=2023-07-16&regionId=6047747&selected=9626574&semdtl=&sort=RECOMMENDED&startDate=2023-07-11&theme=&useRewards=false&userIntent=&vip=false"
#     crawler_flightdataby_LLM(OPENAI_API_KEY,OPENAI_LLM, website_expedia_ticket)
# Out:
# TPE to BKK flights
#
# Skip to main contentaccountBeginning of main contentSelect your departure to BangkokCurrent: Choose departing flightChoose departing flightChoose returning flightReview your tripPrices displayed include taxes and may change based on availability. You can review any additional fees before checkout. Prices are not final until you complete your purchase.Search resultsTigerair Taiwan flight departing at 6:20pm from NT$6,9896:20pm - 9:10pmTaipei (TPE) - Bangkok (DMK)3h 50m (Nonstop)Tigerair TaiwanNT$6,989NT$6,989Roundtrip per travelerSelect and show fare information for Tigerair Taiwan flight, departing at 6:20pm from Taipei, arriving at 9:10pm in Bangkok, Priced at NT$6,989 Roundtrip per traveler.  3 hours 50 minutes total travel time, Nonstop.Thai AirAsia flight departing at 1:50pm from NT$8,3901:50pm - 4:45pmTaipei (TPE) - Bangkok (DMK)3h 55m (Nonstop)Thai AirAsiaNT$8,390NT$8,390Roundtrip per travelerSelect and show fare information for Thai AirAsia flight, departing at 1:50pm from Taipei, arriving at 4:45pm in Bangkok, Priced at NT$8,390 Roundtrip per traveler.  3 hours 55 minutes total travel time, Nonstop.Thai Lion Mantari flight departing at 12:05am from NT$9,77812:05am - 2:55amTaipei (TPE) - Bangkok (DMK)3h 50m (Nonstop)Thai Lion MantariNT$9,778NT$9,778Roundtrip per travelerSelect and show fare information for Thai Lion Mantari flight, departing at 12:05am from Taipei, arriving at 2:55am in Bangkok, Priced at NT$9,778 Roundtrip per traveler.  3 hours 50 minutes total travel time, Nonstop.Multiple Airlines flight departing at 3:55pm from NT$9,8983:55pm - 7:50am+1Taipei (TPE) - Bangkok (DMK)16h 55m (1 stop)9h 55m in Kuala Lumpur (KUL)Multiple airlinesNT$9,898NT$9,898Roundtrip per travelerSelect and show fare information for multipleAirlines flight, departing at 3:55pm from Taipei, arriving at 7:50am in Bangkok, Priced at NT$9,898 Roundtrip per traveler. Arrives 1 day later. 16 hours 55 minutes total travel time, One stop, Layover for 9 hours 55 minutes in Kuala Lumpur.Multiple Airlines flight departing at 3:55pm from NT$10,2333:55pm - 9:30am+1Taipei (TPE) - Bangkok (DMK)18h 35m (1 stop)11h 40m in Kuala Lumpur (KUL)Multiple airlinesNT$10,233NT$10,233Roundtrip per travelerSelect and show fare information for multipleAirlines flight, departing at 3:55pm from Taipei, arriving at 9:30am in Bangkok, Priced at NT$10,233 Roundtrip per traveler. Arrives 1 day later. 18 hours 35 minutes total travel time, One stop, Layover for 11 hours 40 minutes in Kuala Lumpur.Loading more flights...
#
# Results now sorted by Price (Lowest)
#               flight departure_time departure_terminal flight_hour  \
# 0    Tigerair Taiwan         6:20pm                         3h 50m
# 1       Thai AirAsia         1:50pm                         3h 55m
# 2  Thai Lion Mantari        12:05am                         3h 50m
# 3  Multiple Airlines         3:55pm                        16h 55m
# 4  Multiple Airlines         3:55pm                        18h 35m
#
#   flight_type arrival_time arrival_terminal      price
# 0     Nonstop       9:10pm                    NT$6,989
# 1     Nonstop       4:45pm                    NT$8,390
# 2     Nonstop       2:55am                    NT$9,778
# 3      1 stop     7:50am+1                    NT$9,898
# 4      1 stop     9:30am+1                   NT$10,233

# %%
# read CSV file into a DataFrame
# df = pd.read_csv('ticket_out.csv')
# display(df)
